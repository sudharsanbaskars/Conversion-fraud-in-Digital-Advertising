# %% [markdown]
# # Conversion-fraud-in-Digital-Advertising

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_df = pd.read_csv("Training Data.csv")
click_log = pd.read_csv("click_log.csv")
test_df = pd.read_csv("Test Data.csv")
# Out:
# C:\Users\Sudharsan Baskar\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (22,24,25,26,29,30,31,32,33,34,46,47,48,49,50,51,52,53,54) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
train_df.head()
# Out:
#    clientid_cr                               clmbuserid_cr  conversiontime_cr  \
# 0        75694  31629cd0-0b34-460f-aa61-80c3234e1225-1sjfw       1.620000e+12
# 1        75694  4c98f114-c34c-48f4-84d6-50fc8e9b6d65-10wgg       1.620000e+12
# 2        75694  cd92087a-54b0-4911-bc3d-1144a3c2babd-1sjlg       1.620000e+12
# 3        75694  f79f3de7-5edb-4319-9549-117f47996066-10wrk       1.620000e+12
# 4        30431  01fd1a8a-c3f8-4b57-94ff-66318d0f63c7-1sjts       1.620000e+12
#
#                                     imprid_cr  adslotdimid_cr  algo_cr  \
# 0  01649076-c77f-4d70-afc8-213535427147-1sjd4          321300     38.0
# 1  f84d83b9-b757-4f97-9813-34f8dcc57cc5-1sjfw          129239     38.0
# 2  061edef6-3d9d-408b-884a-ad840e6930ce-10o78          321554     21.0
# 3  0a937239-9091-4bb7-b26b-37d4bb29e50b-10oa0          321300     38.0
# 4  0d46d0d4-8fc6-4d95-aaa1-406354a8400c-1sjo8          355768     21.0
#
#       audiences_cr  clickbid_cr  geodimid_cr            ip_cr  ...  \
# 0          8gw,o3b     2.869316          144  XXX.XXX.XXX.XXX  ...
# 1  8kv,2vk,8gw,2vl     2.790000          144  XXX.XXX.XXX.XXX  ...
# 2          8gw,o3b     2.790000          144  XXX.XXX.XXX.XXX  ...
# 3          8gw,o3b     2.790000          144  XXX.XXX.XXX.XXX  ...
# 4              NaN          NaN          144  XXX.XXX.XXX.XXX  ...
#
#    cityGrpDimId_cr  siteClusterIds_cr  refClusterId_cr  paid_cr spend_cr  \
# 0         348007.0                NaN              NaN      NaN      NaN
# 1         348010.0                NaN              NaN      NaN      NaN
# 2              NaN                NaN              NaN      NaN      NaN
# 3         348007.0                NaN              NaN      NaN      NaN
# 4              NaN                NaN              NaN      1.0    275.0
#
#    attributionType_cr  conversionid_cr  optimize_on_cr  bundleId_cr  \
# 0                 NaN              NaN             NaN          NaN
# 1                 NaN              NaN             NaN          NaN
# 2                 NaN              NaN             NaN          NaN
# 3                 NaN              NaN             NaN          NaN
# 4                 1.0              NaN             NaN          NaN
#
#    conversion_fraud
# 0              True
# 1              True
# 2              True
# 3              True
# 4              True
#
# [5 rows x 56 columns]

# %%
train_df.shape
# Out:
# (965, 56)

# %%
click_log.head()
# Out:
#    Unnamed: 0                                      imprId  \
# 0           0  72efd138-0f6a-4aed-bd3f-9bdd70c0e869-1sjts
# 1           0   210a7e16-6783-46a5-9246-c635db091490-3qpg
# 2           0  179d3fbb-3e10-435d-851d-f65029ef2eb4-10ntc
# 3           0  79ce617b-88bf-46db-8069-6c892df6a306-1sjo8
# 4           0  c8f88058-af7e-4284-8c88-2410d94f82e3-1sjo8
#
#                                    clmbUserId  adSltDimId  \
# 0   e91fcf75-a645-40f6-ab1f-411017d1d19a-631k      207251
# 1   be37dc3a-d12b-4aa5-bd39-1e42ede9d6b9-6mhk      356952
# 2  faceec73-d833-4bd6-b878-3bc27d2638dd-10uao      350086
# 3  113b0b7e-d065-4f14-861e-7bbb49683b15-10u2c      356952
# 4   2b3dac7e-d4dd-4ae7-936d-1f9b4c73493d-h0hg      129239
#
#                                                 auds  \
# 0                            2vv,8k8,8gv,2vk,8gw,joa
# 1                                        8gw,2vb,o3b
# 2                                    2vv,8k8,2vk,8gw
# 3                            2vv,nqv,2vk,8gw,2vb,o3b
# 4  8kv,8j6,8k8,2vk,2vl,8gw,3si,2vt,2vv,nqv,2vb,8l...
#
#                                              allAuds    itemid  algo  \
# 0  7dm,cy9,5b2,oy7,p98,lo4,p12,p16,apc,p18,nqy,ic...  52696204    18
# 1  hkf,n5n,59j,p9q,n3p,p9t,o1o,41j,o1n,nyw,n3s,n5...  53622457    18
# 2  o1j,o1o,oy7,o1n,nyw,oww,lo4,p12,apc,358,5o2,o6...  53622457    38
# 3  n7j,pf9,n90,n91,n98,o1o,nyw,o1n,lo4,nqv,igs,ap...  53622457    38
# 4  n7j,nyw,592,n7x,n7z,qq5,apc,n8a,359,n8e,n8g,ap...  53622457    38
#
#    advClientId  pubClientId  ...  devTypeDimId  vendorDimId modelDimId  \
# 0          330         2310  ...      196047.0       196460     202038
# 1          330        85030  ...      196047.0       196460     202038
# 2          330         2658  ...      196047.0       196460     202038
# 3          330        85030  ...      196047.0       196460     202038
# 4          330        15240  ...      196047.0       196460     202038
#
#    connTypeDimId browserDimId  refClusterId  fraud  cpa imprUserId  optout
# 0         264494       129639           NaN    NaN  NaN        NaN     NaN
# 1         264496       129639           NaN    NaN  NaN        NaN     NaN
# 2         264496       129639           NaN    NaN  NaN        NaN     NaN
# 3         264496       129639           NaN    NaN  NaN        NaN     NaN
# 4         264494       129639           NaN    NaN  NaN        NaN     NaN
#
# [5 rows x 55 columns]

# %%
click_log.shape
# Out:
# (244864, 55)

# %%
test_df.head()
# Out:
#    record_id  clientid_cr                               clmbuserid_cr  \
# 0       1000        82122   1045e8b8-662e-49b3-bc4a-4af5326c8236-62kw
# 1       1001        75694  53a9a707-967d-4a67-8e9f-e3dd55b464e8-10wm0
# 2       1002        75694  53a9a707-967d-4a67-8e9f-e3dd55b464e8-10wm0
# 3       1003        30431  5febd7e2-b66a-4af0-91ec-117557684188-10wrk
# 4       1004        30431  5febd7e2-b66a-4af0-91ec-117557684188-10wrk
#
#    conversiontime_cr                                   imprid_cr  \
# 0      1620000000000  864cdaf0-cca7-4bcc-b210-a33858cf8755-1siz8
# 1      1620000000000  6c44c171-9445-4e6b-856e-89bfcd0be22c-1sito
# 2      1620000000000  c00eae97-46c5-48b8-89bf-9d45628b9de3-1siz8
# 3      1620000000000  40aad66c-d2da-4635-8b5e-46aca58d2dc6-10o78
# 4      1620000000000  4742d072-32ed-45bc-9ca9-5dca4a69f5b1-10onw
#
#    adslotdimid_cr  algo_cr audiences_cr  clickbid_cr  geodimid_cr  ...  \
# 0          233531       38          NaN          NaN          145  ...
# 1          356952       20          NaN          3.1          144  ...
# 2          356952       18          NaN          3.1          144  ...
# 3          355768       21          NaN          NaN          144  ...
# 4          355768       21          NaN          NaN          144  ...
#
#   usrClusterId_cr  cityGrpDimId_cr  siteClusterIds_cr  refClusterId_cr  \
# 0             NaN              NaN       3.337341e+17              NaN
# 1             NaN         348006.0                NaN              NaN
# 2             NaN         348006.0                NaN              NaN
# 3             NaN         348010.0                NaN              NaN
# 4             NaN         348010.0                NaN              NaN
#
#    paid_cr spend_cr  attributionType_cr  conversionid_cr  optimize_on_cr  \
# 0      NaN      NaN                 NaN              NaN             NaN
# 1      NaN      NaN                 NaN              NaN             NaN
# 2      NaN      NaN                 NaN              NaN             NaN
# 3      1.0    275.0                 1.0              NaN             NaN
# 4      1.0    275.0                 1.0              NaN             NaN
#
#    bundleId_cr
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 56 columns]

# %%
train_df.columns
# Out:
# Index(['clientid_cr', 'clmbuserid_cr', 'conversiontime_cr', 'imprid_cr',
#        'adslotdimid_cr', 'algo_cr', 'audiences_cr', 'clickbid_cr',
#        'geodimid_cr', 'ip_cr', 'itemcolumbiaid_cr', 'itemid_cr', 'position_cr',
#        'pubclientid_cr', 'refurl_cr', 'siteId_cr', 'templateid_cr',
#        'goalid_cr', 'time_cr', 'adLogType_cr', 'v_cr', 'allAudiences_cr',
#        'pricingtype_cr', 'osId_cr', 'browserId_cr', 'cityId_cr', 'stateId_cr',
#        'modelDimId_cr', 'lookUpFrom_cr', 'connTypeDimId_cr', 'ispDimId_cr',
#        'countryDimId_cr', 'goalTypeId_cr', 'conversionDurationInMillis_cr',
#        'impressionTimeInMillis_cr', 'clickTimeInMillis_cr', 'osVerDimId_cr',
#        'uuidSource_cr', 'geoGrpDimId_cr', 'stateGrpDimId_cr', 'deviceId_cr',
#        'uvh_cr', 'uv_cr', 'platformId_cr', 'sdkVersion_cr', 'usrClusterId_cr',
#        'cityGrpDimId_cr', 'siteClusterIds_cr', 'refClusterId_cr', 'paid_cr',
#        'spend_cr', 'attributionType_cr', 'conversionid_cr', 'optimize_on_cr',
#        'bundleId_cr', 'conversion_fraud'],
#       dtype='object')

# %%
len(train_df.columns)
# Out:
# 56

# %% [markdown]
# ### Data Preprocessing and Feature Engineering

# %% [markdown]
# #### Let's fill the empty cells

# %%
train_df.isnull().sum()
# Out:
# clientid_cr                        0
# clmbuserid_cr                      0
# conversiontime_cr                  0
# imprid_cr                          0
# adslotdimid_cr                     0
# algo_cr                           20
# audiences_cr                     199
# clickbid_cr                      296
# geodimid_cr                        0
# ip_cr                             20
# itemcolumbiaid_cr                  0
# itemid_cr                          0
# position_cr                       20
# pubclientid_cr                     0
# refurl_cr                        125
# siteId_cr                          0
# templateid_cr                    107
# goalid_cr                          0
# time_cr                            0
# adLogType_cr                       0
# v_cr                               1
# allAudiences_cr                   47
# pricingtype_cr                     0
# osId_cr                           21
# browserId_cr                      21
# cityId_cr                         20
# stateId_cr                        20
# modelDimId_cr                     21
# lookUpFrom_cr                      0
# connTypeDimId_cr                  20
# ispDimId_cr                       20
# countryDimId_cr                   20
# goalTypeId_cr                      0
# conversionDurationInMillis_cr     20
# impressionTimeInMillis_cr         20
# clickTimeInMillis_cr             132
# osVerDimId_cr                     21
# uuidSource_cr                     20
# geoGrpDimId_cr                    20
# stateGrpDimId_cr                 105
# deviceId_cr                      854
# uvh_cr                           965
# uv_cr                            936
# platformId_cr                    853
# sdkVersion_cr                    958
# usrClusterId_cr                  611
# cityGrpDimId_cr                  344
# siteClusterIds_cr                553
# refClusterId_cr                  899
# paid_cr                          771
# spend_cr                         771
# attributionType_cr               771
# conversionid_cr                  941
# optimize_on_cr                   925
# bundleId_cr                      960
# conversion_fraud                   0
# dtype: int64

# %%
train_df.isnull().mean()*100
# Out:
# clientid_cr                        0.000000
# clmbuserid_cr                      0.000000
# conversiontime_cr                  0.000000
# imprid_cr                          0.000000
# adslotdimid_cr                     0.000000
# algo_cr                            2.072539
# audiences_cr                      20.621762
# clickbid_cr                       30.673575
# geodimid_cr                        0.000000
# ip_cr                              2.072539
# itemcolumbiaid_cr                  0.000000
# itemid_cr                          0.000000
# position_cr                        2.072539
# pubclientid_cr                     0.000000
# refurl_cr                         12.953368
# siteId_cr                          0.000000
# templateid_cr                     11.088083
# goalid_cr                          0.000000
# time_cr                            0.000000
# adLogType_cr                       0.000000
# v_cr                               0.103627
# allAudiences_cr                    4.870466
# pricingtype_cr                     0.000000
# osId_cr                            2.176166
# browserId_cr                       2.176166
# cityId_cr                          2.072539
# stateId_cr                         2.072539
# modelDimId_cr                      2.176166
# lookUpFrom_cr                      0.000000
# connTypeDimId_cr                   2.072539
# ispDimId_cr                        2.072539
# countryDimId_cr                    2.072539
# goalTypeId_cr                      0.000000
# conversionDurationInMillis_cr      2.072539
# impressionTimeInMillis_cr          2.072539
# clickTimeInMillis_cr              13.678756
# osVerDimId_cr                      2.176166
# uuidSource_cr                      2.072539
# geoGrpDimId_cr                     2.072539
# stateGrpDimId_cr                  10.880829
# deviceId_cr                       88.497409
# uvh_cr                           100.000000
# uv_cr                             96.994819
# platformId_cr                     88.393782
# sdkVersion_cr                     99.274611
# usrClusterId_cr                   63.316062
# cityGrpDimId_cr                   35.647668
# siteClusterIds_cr                 57.305699
# refClusterId_cr                   93.160622
# paid_cr                           79.896373
# spend_cr                          79.896373
# attributionType_cr                79.896373
# conversionid_cr                   97.512953
# optimize_on_cr                    95.854922
# bundleId_cr                       99.481865
# conversion_fraud                   0.000000
# dtype: float64

# %% [markdown]
# #### Let's drop the features first which are having more than 40% of the NAN values

# %%
features_not_needed = []
for feature in train_df.columns:
    if train_df[feature].isnull().mean()*100 >= 40:
        features_not_needed.append(feature)

# %%
features_not_needed
# Out:
# ['deviceId_cr',
#  'uvh_cr',
#  'uv_cr',
#  'platformId_cr',
#  'sdkVersion_cr',
#  'usrClusterId_cr',
#  'siteClusterIds_cr',
#  'refClusterId_cr',
#  'paid_cr',
#  'spend_cr',
#  'attributionType_cr',
#  'conversionid_cr',
#  'optimize_on_cr',
#  'bundleId_cr']

# %%
train_df = train_df.drop(features_not_needed, axis = "columns")

# %%
train_df.shape
# Out:
# (965, 42)

# %% [markdown]
# #### Let us fill the missing values in the numerical features first

# %%
def null_values(df, feature_list):
    for col in feature_list:
        print(col, "-->", df[col].isnull().mean()*100)

# %%
numerical_features = [feature for feature in train_df.columns if train_df[feature].dtypes != 'O']
numerical_features
# Out:
# ['clientid_cr',
#  'conversiontime_cr',
#  'adslotdimid_cr',
#  'algo_cr',
#  'clickbid_cr',
#  'geodimid_cr',
#  'itemcolumbiaid_cr',
#  'itemid_cr',
#  'position_cr',
#  'pubclientid_cr',
#  'siteId_cr',
#  'templateid_cr',
#  'goalid_cr',
#  'time_cr',
#  'adLogType_cr',
#  'v_cr',
#  'pricingtype_cr',
#  'osId_cr',
#  'browserId_cr',
#  'cityId_cr',
#  'stateId_cr',
#  'modelDimId_cr',
#  'lookUpFrom_cr',
#  'ispDimId_cr',
#  'countryDimId_cr',
#  'goalTypeId_cr',
#  'conversionDurationInMillis_cr',
#  'impressionTimeInMillis_cr',
#  'clickTimeInMillis_cr',
#  'osVerDimId_cr',
#  'uuidSource_cr',
#  'geoGrpDimId_cr',
#  'stateGrpDimId_cr',
#  'cityGrpDimId_cr',
#  'conversion_fraud']

# %%
null_values(train_df, numerical_features)
# Out:
# clientid_cr --> 0.0
# conversiontime_cr --> 0.0
# adslotdimid_cr --> 0.0
# algo_cr --> 2.072538860103627
# clickbid_cr --> 30.67357512953368
# geodimid_cr --> 0.0
# itemcolumbiaid_cr --> 0.0
# itemid_cr --> 0.0
# position_cr --> 2.072538860103627
# pubclientid_cr --> 0.0
# siteId_cr --> 0.0
# templateid_cr --> 11.088082901554404
# goalid_cr --> 0.0
# time_cr --> 0.0
# adLogType_cr --> 0.0
# v_cr --> 0.10362694300518134
# pricingtype_cr --> 0.0
# osId_cr --> 2.1761658031088085
# browserId_cr --> 2.1761658031088085
# cityId_cr --> 2.072538860103627
# stateId_cr --> 2.072538860103627
# modelDimId_cr --> 2.1761658031088085
# lookUpFrom_cr --> 0.0
# ispDimId_cr --> 2.072538860103627
# countryDimId_cr --> 2.072538860103627
# goalTypeId_cr --> 0.0
# conversionDurationInMillis_cr --> 2.072538860103627
# impressionTimeInMillis_cr --> 2.072538860103627
# clickTimeInMillis_cr --> 13.678756476683937
# osVerDimId_cr --> 2.1761658031088085
# uuidSource_cr --> 2.072538860103627
# geoGrpDimId_cr --> 2.072538860103627
# stateGrpDimId_cr --> 10.880829015544041
# cityGrpDimId_cr --> 35.64766839378238
# conversion_fraud --> 0.0

# %%
numerical_features_with_nan = [feature for feature in numerical_features if train_df[feature].isnull().mean() != 0]

# %%
numerical_features_with_nan
# Out:
# ['algo_cr',
#  'clickbid_cr',
#  'position_cr',
#  'templateid_cr',
#  'v_cr',
#  'osId_cr',
#  'browserId_cr',
#  'cityId_cr',
#  'stateId_cr',
#  'modelDimId_cr',
#  'ispDimId_cr',
#  'countryDimId_cr',
#  'conversionDurationInMillis_cr',
#  'impressionTimeInMillis_cr',
#  'clickTimeInMillis_cr',
#  'osVerDimId_cr',
#  'uuidSource_cr',
#  'geoGrpDimId_cr',
#  'stateGrpDimId_cr',
#  'cityGrpDimId_cr']

# %%
def plot_hist(df, feature):
    plt.hist(df[feature], color='green')
    plt.title(feature)
    plt.show()

# %%
for feature in numerical_features_with_nan:
    plot_hist(train_df, feature)

# %% [markdown]
# ##### Seems majority of the features are discrete numerical variables

# %% [markdown]
# ##### Let's fill the missing values using random sample imputation

# %%
def impute_nan(df,variable):
    ##It will have the random sample to fill the na
    random_sample=df[variable].dropna().sample(df[variable].isnull().sum(),random_state=0)
    ##pandas need to have same index in order to merge the dataset
    random_sample.index=df[df[variable].isnull()].index
    df.loc[df[variable].isnull(),variable]=random_sample

# %%
for feature in numerical_features_with_nan:
    impute_nan(train_df, feature)

# %%
train_df.shape
# Out:
# (965, 42)

# %%
train_df.head()
# Out:
#    clientid_cr                               clmbuserid_cr  conversiontime_cr  \
# 0        75694  31629cd0-0b34-460f-aa61-80c3234e1225-1sjfw       1.620000e+12
# 1        75694  4c98f114-c34c-48f4-84d6-50fc8e9b6d65-10wgg       1.620000e+12
# 2        75694  cd92087a-54b0-4911-bc3d-1144a3c2babd-1sjlg       1.620000e+12
# 3        75694  f79f3de7-5edb-4319-9549-117f47996066-10wrk       1.620000e+12
# 4        30431  01fd1a8a-c3f8-4b57-94ff-66318d0f63c7-1sjts       1.620000e+12
#
#                                     imprid_cr  adslotdimid_cr  algo_cr  \
# 0  01649076-c77f-4d70-afc8-213535427147-1sjd4          321300     38.0
# 1  f84d83b9-b757-4f97-9813-34f8dcc57cc5-1sjfw          129239     38.0
# 2  061edef6-3d9d-408b-884a-ad840e6930ce-10o78          321554     21.0
# 3  0a937239-9091-4bb7-b26b-37d4bb29e50b-10oa0          321300     38.0
# 4  0d46d0d4-8fc6-4d95-aaa1-406354a8400c-1sjo8          355768     21.0
#
#       audiences_cr  clickbid_cr  geodimid_cr            ip_cr  ...  \
# 0          8gw,o3b     2.869316          144  XXX.XXX.XXX.XXX  ...
# 1  8kv,2vk,8gw,2vl     2.790000          144  XXX.XXX.XXX.XXX  ...
# 2          8gw,o3b     2.790000          144  XXX.XXX.XXX.XXX  ...
# 3          8gw,o3b     2.790000          144  XXX.XXX.XXX.XXX  ...
# 4              NaN     2.790000          144  XXX.XXX.XXX.XXX  ...
#
#    goalTypeId_cr  conversionDurationInMillis_cr  impressionTimeInMillis_cr  \
# 0             10                         2332.0               1.620000e+12
# 1             10                         3201.0               1.620000e+12
# 2             10                         2821.0               1.620000e+12
# 3             10                         3144.0               1.620000e+12
# 4             10                        42597.0               1.620000e+12
#
#    clickTimeInMillis_cr osVerDimId_cr  uuidSource_cr  geoGrpDimId_cr  \
# 0          1.620000e+12      199452.0            1.0        348011.0
# 1          1.620000e+12      199452.0            1.0        348011.0
# 2          1.620000e+12      199452.0            1.0        348011.0
# 3          1.620000e+12      199452.0            1.0        348011.0
# 4          1.620000e+12      360833.0            1.0        348011.0
#
#    stateGrpDimId_cr  cityGrpDimId_cr  conversion_fraud
# 0          348022.0         348007.0              True
# 1          348024.0         348010.0              True
# 2          348027.0         348005.0              True
# 3          348023.0         348007.0              True
# 4          348025.0         348007.0              True
#
# [5 rows x 42 columns]

# %%
null_values(train_df, numerical_features_with_nan)
# Out:
# algo_cr --> 0.0
# clickbid_cr --> 0.0
# position_cr --> 0.0
# templateid_cr --> 0.0
# v_cr --> 0.0
# osId_cr --> 0.0
# browserId_cr --> 0.0
# cityId_cr --> 0.0
# stateId_cr --> 0.0
# modelDimId_cr --> 0.0
# ispDimId_cr --> 0.0
# countryDimId_cr --> 0.0
# conversionDurationInMillis_cr --> 0.0
# impressionTimeInMillis_cr --> 0.0
# clickTimeInMillis_cr --> 0.0
# osVerDimId_cr --> 0.0
# uuidSource_cr --> 0.0
# geoGrpDimId_cr --> 0.0
# stateGrpDimId_cr --> 0.0
# cityGrpDimId_cr --> 0.0

# %% [markdown]
# #### Filling the missing values in catagorical features

# %%
categorical_features = [feature for feature in train_df.columns if train_df[feature].dtype == 'O' ]

# %%
categorical_features_with_nan = [feature for feature in categorical_features if train_df[feature].isnull().mean() != 0 ]
categorical_features_with_nan
# Out:
# ['audiences_cr', 'ip_cr', 'refurl_cr', 'allAudiences_cr', 'connTypeDimId_cr']

# %%
null_values(train_df, categorical_features_with_nan)
# Out:
# audiences_cr --> 20.621761658031087
# ip_cr --> 2.072538860103627
# refurl_cr --> 12.953367875647666
# allAudiences_cr --> 4.870466321243523
# connTypeDimId_cr --> 2.072538860103627

# %%
for feature in categorical_features_with_nan:
    print(feature, "-->", len(train_df[feature].unique()))
# Out:
# audiences_cr --> 441
# ip_cr --> 2
# refurl_cr --> 400
# allAudiences_cr --> 821
# connTypeDimId_cr --> 10

# %%
train_df['ip_cr'].value_counts()
# Out:
# XXX.XXX.XXX.XXX    945
# Name: ip_cr, dtype: int64

# %%
#### Seems that this feature ip_cr dosen't contain any valuable information, so let us drop it
train_df.drop(['ip_cr'], axis="columns", inplace=True)

# %% [markdown]
# #### let us use the random sample imputation technique to fill the missing values

# %%
categorical_features_with_nan.remove('ip_cr')

# %%
for feature in categorical_features_with_nan:
    impute_nan(train_df, feature)

# %%
null_values(train_df, categorical_features_with_nan)
# Out:
# audiences_cr --> 0.0
# refurl_cr --> 0.0
# allAudiences_cr --> 0.0
# connTypeDimId_cr --> 0.0

# %%
train_df.isnull().mean()
# Out:
# clientid_cr                      0.0
# clmbuserid_cr                    0.0
# conversiontime_cr                0.0
# imprid_cr                        0.0
# adslotdimid_cr                   0.0
# algo_cr                          0.0
# audiences_cr                     0.0
# clickbid_cr                      0.0
# geodimid_cr                      0.0
# itemcolumbiaid_cr                0.0
# itemid_cr                        0.0
# position_cr                      0.0
# pubclientid_cr                   0.0
# refurl_cr                        0.0
# siteId_cr                        0.0
# templateid_cr                    0.0
# goalid_cr                        0.0
# time_cr                          0.0
# adLogType_cr                     0.0
# v_cr                             0.0
# allAudiences_cr                  0.0
# pricingtype_cr                   0.0
# osId_cr                          0.0
# browserId_cr                     0.0
# cityId_cr                        0.0
# stateId_cr                       0.0
# modelDimId_cr                    0.0
# lookUpFrom_cr                    0.0
# connTypeDimId_cr                 0.0
# ispDimId_cr                      0.0
# countryDimId_cr                  0.0
# goalTypeId_cr                    0.0
# conversionDurationInMillis_cr    0.0
# impressionTimeInMillis_cr        0.0
# clickTimeInMillis_cr             0.0
# osVerDimId_cr                    0.0
# uuidSource_cr                    0.0
# geoGrpDimId_cr                   0.0
# stateGrpDimId_cr                 0.0
# cityGrpDimId_cr                  0.0
# conversion_fraud                 0.0
# dtype: float64

# %%
train_df['conversiontime_cr'].unique()
# Out:
# array([1.62e+12])

# %% [markdown]
# ##### Now our dataset has no nan values 👍🙌

# %% [markdown]
# ### Feature Selection using Pearson Correlation

# %%
corrmat = train_df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(30,30))
g=sns.heatmap(train_df.corr(),annot=True,cmap="RdYlGn")

# %% [markdown]
# #### From the above correlation matrix, we can infer that there are many features which are highly correlated with other features

# %% [markdown]
# #### Let us find and remove the highly features by using the following function

# %%
#with the following function we can select highly correlated features
# it will remove the first feature that is correlated with anything other feature

def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if (corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
list(correlation(train_df, 0.85))
# Out:
# ['clickTimeInMillis_cr', 'lookUpFrom_cr', 'geoGrpDimId_cr']

# %%
### Here i am choosing the thresold value as 0.85 and dropping the highly correlated features
train_df.drop(correlation(train_df, 0.85), axis="columns", inplace=True)

# %%
train_df.columns
# Out:
# Index(['clientid_cr', 'clmbuserid_cr', 'conversiontime_cr', 'imprid_cr',
#        'adslotdimid_cr', 'algo_cr', 'audiences_cr', 'clickbid_cr',
#        'geodimid_cr', 'itemcolumbiaid_cr', 'itemid_cr', 'position_cr',
#        'pubclientid_cr', 'refurl_cr', 'siteId_cr', 'templateid_cr',
#        'goalid_cr', 'time_cr', 'adLogType_cr', 'v_cr', 'allAudiences_cr',
#        'pricingtype_cr', 'osId_cr', 'browserId_cr', 'cityId_cr', 'stateId_cr',
#        'modelDimId_cr', 'connTypeDimId_cr', 'ispDimId_cr', 'countryDimId_cr',
#        'goalTypeId_cr', 'conversionDurationInMillis_cr',
#        'impressionTimeInMillis_cr', 'osVerDimId_cr', 'uuidSource_cr',
#        'stateGrpDimId_cr', 'cityGrpDimId_cr', 'conversion_fraud'],
#       dtype='object')

# %%
train_df.shape
# Out:
# (965, 38)

# %%
train_df.head(10)
# Out:
#    clientid_cr                               clmbuserid_cr  conversiontime_cr  \
# 0        75694  31629cd0-0b34-460f-aa61-80c3234e1225-1sjfw       1.620000e+12
# 1        75694  4c98f114-c34c-48f4-84d6-50fc8e9b6d65-10wgg       1.620000e+12
# 2        75694  cd92087a-54b0-4911-bc3d-1144a3c2babd-1sjlg       1.620000e+12
# 3        75694  f79f3de7-5edb-4319-9549-117f47996066-10wrk       1.620000e+12
# 4        30431  01fd1a8a-c3f8-4b57-94ff-66318d0f63c7-1sjts       1.620000e+12
# 5        75694  4c98f114-c34c-48f4-84d6-50fc8e9b6d65-10wgg       1.620000e+12
# 6        75694  10a967f6-c991-4f33-a212-9b42c8a60126-10w2k       1.620000e+12
# 7        75694  6ad61f5f-bf5a-445d-a314-930e94e47fbc-1sjfw       1.620000e+12
# 8        82122   59582f67-7cd3-4748-82d4-15928b166533-6mc0       1.620000e+12
# 9        75694  224654bd-4798-4e62-8c15-72b4ba6cc379-10ol4       1.620000e+12
#
#                                     imprid_cr  adslotdimid_cr  algo_cr  \
# 0  01649076-c77f-4d70-afc8-213535427147-1sjd4          321300     38.0
# 1  f84d83b9-b757-4f97-9813-34f8dcc57cc5-1sjfw          129239     38.0
# 2  061edef6-3d9d-408b-884a-ad840e6930ce-10o78          321554     21.0
# 3  0a937239-9091-4bb7-b26b-37d4bb29e50b-10oa0          321300     38.0
# 4  0d46d0d4-8fc6-4d95-aaa1-406354a8400c-1sjo8          355768     21.0
# 5  f84d83b9-b757-4f97-9813-34f8dcc57cc5-1sjfw          129239     38.0
# 6  0fe0e58a-4e84-43f7-97e5-703201ba01fe-1sk24          321300     38.0
# 7   f6a9c4e0-8c85-49ce-af8d-d0c6b7288da2-h0hg          355900     39.0
# 8  f6885674-956c-485d-8009-68c10b1e39e4-10ocs          233531     21.0
# 9  f656acb7-8d86-4695-9ffe-0d3da73517b8-10ol4          356952     18.0
#
#               audiences_cr  clickbid_cr  geodimid_cr  itemcolumbiaid_cr  ...  \
# 0                  8gw,o3b     2.869316          144            5488088  ...
# 1          8kv,2vk,8gw,2vl     2.790000          144            5488773  ...
# 2                  8gw,o3b     2.790000          144            5488088  ...
# 3                  8gw,o3b     2.790000          144            5488088  ...
# 4          8kv,2vk,8gw,2vl     2.790000          144            5614054  ...
# 5          8kv,2vk,8gw,2vl     2.790000          144            5488773  ...
# 6                  8gw,o3b     3.100000          144            5488088  ...
# 7              2vk,8gw,job     3.100000          144            5488773  ...
# 8                      8gw     1.000000          145            5526656  ...
# 9  8kv,2vk,8gw,2vl,2vb,o3b     3.100000          144            5488088  ...
#
#    ispDimId_cr  countryDimId_cr  goalTypeId_cr conversionDurationInMillis_cr  \
# 0     280429.0            144.0             10                        2332.0
# 1     136127.0            144.0             10                        3201.0
# 2     172725.0            144.0             10                        2821.0
# 3     136127.0            144.0             10                        3144.0
# 4     136127.0            144.0             10                       42597.0
# 5     136127.0            144.0             10                        1237.0
# 6     136127.0            144.0             10                        2632.0
# 7     150208.0            144.0             10                        5931.0
# 8     265618.0            145.0             10                       14810.0
# 9     280429.0            144.0             10                        8901.0
#
#    impressionTimeInMillis_cr  osVerDimId_cr  uuidSource_cr  stateGrpDimId_cr  \
# 0               1.620000e+12       199452.0            1.0          348022.0
# 1               1.620000e+12       199452.0            1.0          348024.0
# 2               1.620000e+12       199452.0            1.0          348027.0
# 3               1.620000e+12       199452.0            1.0          348023.0
# 4               1.620000e+12       360833.0            1.0          348025.0
# 5               1.620000e+12       199452.0            1.0          348024.0
# 6               1.620000e+12       199452.0            1.0          348023.0
# 7               1.620000e+12       199414.0            1.0          348024.0
# 8               1.620000e+12            0.0            1.0          348022.0
# 9               1.620000e+12       199452.0            1.0          348023.0
#
#    cityGrpDimId_cr  conversion_fraud
# 0         348007.0              True
# 1         348010.0              True
# 2         348005.0              True
# 3         348007.0              True
# 4         348007.0              True
# 5         348010.0              True
# 6         348007.0              True
# 7         348005.0              True
# 8         348007.0              True
# 9         348007.0              True
#
# [10 rows x 38 columns]

# %% [markdown]
# #### Let's check the other catogorical features

# %%
train_df['clmbuserid_cr']
# Out:
# 0      31629cd0-0b34-460f-aa61-80c3234e1225-1sjfw
# 1      4c98f114-c34c-48f4-84d6-50fc8e9b6d65-10wgg
# 2      cd92087a-54b0-4911-bc3d-1144a3c2babd-1sjlg
# 3      f79f3de7-5edb-4319-9549-117f47996066-10wrk
# 4      01fd1a8a-c3f8-4b57-94ff-66318d0f63c7-1sjts
#                           ...
# 960          41d7dab3-0ab7-4039-a936-2ceab9dbcbf7
# 961          39511cf3-0358-4ae9-9fec-fe3a74e98a13
# 962    e5d4037f-ec67-4d7b-8d83-9012ee7d64b9-1sjac
# 963    c7491247-f203-48df-b08d-d25d0d873e20-1sjwk
# 964     20dcb941-42eb-4f0c-8f96-7afe12146264-h0k8
# Name: clmbuserid_cr, Length: 965, dtype: object

# %%
len(train_df['clmbuserid_cr'].unique())
# Out:
# 896

# %%
train_df['imprid_cr']
# Out:
# 0      01649076-c77f-4d70-afc8-213535427147-1sjd4
# 1      f84d83b9-b757-4f97-9813-34f8dcc57cc5-1sjfw
# 2      061edef6-3d9d-408b-884a-ad840e6930ce-10o78
# 3      0a937239-9091-4bb7-b26b-37d4bb29e50b-10oa0
# 4      0d46d0d4-8fc6-4d95-aaa1-406354a8400c-1sjo8
#                           ...
# 960    a9371035-94c0-49a9-b807-70e472bb31a9-1sk24
# 961    a955a5eb-1f0f-4654-8381-9f709bb98a7a-10ni8
# 962    a97061e8-4863-440a-956c-14c85984c29e-10nw4
# 963    a974732d-bfa0-4018-b216-b2d1c97f3337-1sj7k
# 964    a9794d23-4f67-4446-8c34-6fb608435f40-1siz8
# Name: imprid_cr, Length: 965, dtype: object

# %%
len(train_df['imprid_cr'].unique())
# Out:
# 934

# %%
train_df['audiences_cr']
# Out:
# 0                                                8gw,o3b
# 1                                        8kv,2vk,8gw,2vl
# 2                                                8gw,o3b
# 3                                                8gw,o3b
# 4                                        8kv,2vk,8gw,2vl
#                              ...
# 960    8go,8gr,8k6,8h4,8gv,2vk,8gw,8iy,3si,2x6,nqv,2v...
# 961                      2x6,8k6,8k8,30r,8gv,2vk,8gw,8j1
# 962                                  2vv,2vk,8gw,2vb,o3b
# 963                                          nqv,2vk,8gw
# 964                                                  8gv
# Name: audiences_cr, Length: 965, dtype: object

# %%
len(train_df['audiences_cr'].unique())
# Out:
# 440

# %% [markdown]
# ##### Seems these catogorical features are not having any valuable inforamtion and if we do one-hot-encoding,then we may face the issue of "Curse of Dimensionality".
# ##### So i will  drop those features

# %%
train_df.drop(['clmbuserid_cr', 'imprid_cr', 'audiences_cr'], axis="columns", inplace=True)

# %%
train_df.head()
# Out:
#    clientid_cr  conversiontime_cr  adslotdimid_cr  algo_cr  clickbid_cr  \
# 0        75694       1.620000e+12          321300     38.0     2.869316
# 1        75694       1.620000e+12          129239     38.0     2.790000
# 2        75694       1.620000e+12          321554     21.0     2.790000
# 3        75694       1.620000e+12          321300     38.0     2.790000
# 4        30431       1.620000e+12          355768     21.0     2.790000
#
#    geodimid_cr  itemcolumbiaid_cr  itemid_cr  position_cr  pubclientid_cr  \
# 0          144            5488088   49504155          1.0            2320
# 1          144            5488773   49504157          1.0           15240
# 2          144            5488088   49504160          1.0            2320
# 3          144            5488088   49504155          1.0            2320
# 4          144            5614054   53607445          1.0               1
#
#    ... ispDimId_cr  countryDimId_cr  goalTypeId_cr  \
# 0  ...    280429.0            144.0             10
# 1  ...    136127.0            144.0             10
# 2  ...    172725.0            144.0             10
# 3  ...    136127.0            144.0             10
# 4  ...    136127.0            144.0             10
#
#    conversionDurationInMillis_cr  impressionTimeInMillis_cr  osVerDimId_cr  \
# 0                         2332.0               1.620000e+12       199452.0
# 1                         3201.0               1.620000e+12       199452.0
# 2                         2821.0               1.620000e+12       199452.0
# 3                         3144.0               1.620000e+12       199452.0
# 4                        42597.0               1.620000e+12       360833.0
#
#    uuidSource_cr stateGrpDimId_cr  cityGrpDimId_cr  conversion_fraud
# 0            1.0         348022.0         348007.0              True
# 1            1.0         348024.0         348010.0              True
# 2            1.0         348027.0         348005.0              True
# 3            1.0         348023.0         348007.0              True
# 4            1.0         348025.0         348007.0              True
#
# [5 rows x 35 columns]

# %%
train_df.dtypes
# Out:
# clientid_cr                        int64
# conversiontime_cr                float64
# adslotdimid_cr                     int64
# algo_cr                          float64
# clickbid_cr                      float64
# geodimid_cr                        int64
# itemcolumbiaid_cr                  int64
# itemid_cr                          int64
# position_cr                      float64
# pubclientid_cr                     int64
# refurl_cr                         object
# siteId_cr                          int64
# templateid_cr                    float64
# goalid_cr                          int64
# time_cr                          float64
# adLogType_cr                       int64
# v_cr                             float64
# allAudiences_cr                   object
# pricingtype_cr                     int64
# osId_cr                          float64
# browserId_cr                     float64
# cityId_cr                        float64
# stateId_cr                       float64
# modelDimId_cr                    float64
# connTypeDimId_cr                  object
# ispDimId_cr                      float64
# countryDimId_cr                  float64
# goalTypeId_cr                      int64
# conversionDurationInMillis_cr    float64
# impressionTimeInMillis_cr        float64
# osVerDimId_cr                    float64
# uuidSource_cr                    float64
# stateGrpDimId_cr                 float64
# cityGrpDimId_cr                  float64
# conversion_fraud                    bool
# dtype: object

# %%
train_df.head(10)
# Out:
#    clientid_cr  conversiontime_cr  adslotdimid_cr  algo_cr  clickbid_cr  \
# 0        75694       1.620000e+12          321300     38.0     2.869316
# 1        75694       1.620000e+12          129239     38.0     2.790000
# 2        75694       1.620000e+12          321554     21.0     2.790000
# 3        75694       1.620000e+12          321300     38.0     2.790000
# 4        30431       1.620000e+12          355768     21.0     2.790000
# 5        75694       1.620000e+12          129239     38.0     2.790000
# 6        75694       1.620000e+12          321300     38.0     3.100000
# 7        75694       1.620000e+12          355900     39.0     3.100000
# 8        82122       1.620000e+12          233531     21.0     1.000000
# 9        75694       1.620000e+12          356952     18.0     3.100000
#
#    geodimid_cr  itemcolumbiaid_cr  itemid_cr  position_cr  pubclientid_cr  \
# 0          144            5488088   49504155          1.0            2320
# 1          144            5488773   49504157          1.0           15240
# 2          144            5488088   49504160          1.0            2320
# 3          144            5488088   49504155          1.0            2320
# 4          144            5614054   53607445          1.0               1
# 5          144            5488773   49504157          1.0           15240
# 6          144            5488088   49504155          2.0            2320
# 7          144            5488773   49504155          1.0            2308
# 8          145            5526656   47164455          2.0            2658
# 9          144            5488088   49504160          1.0           85030
#
#    ... ispDimId_cr  countryDimId_cr  goalTypeId_cr  \
# 0  ...    280429.0            144.0             10
# 1  ...    136127.0            144.0             10
# 2  ...    172725.0            144.0             10
# 3  ...    136127.0            144.0             10
# 4  ...    136127.0            144.0             10
# 5  ...    136127.0            144.0             10
# 6  ...    136127.0            144.0             10
# 7  ...    150208.0            144.0             10
# 8  ...    265618.0            145.0             10
# 9  ...    280429.0            144.0             10
#
#    conversionDurationInMillis_cr  impressionTimeInMillis_cr  osVerDimId_cr  \
# 0                         2332.0               1.620000e+12       199452.0
# 1                         3201.0               1.620000e+12       199452.0
# 2                         2821.0               1.620000e+12       199452.0
# 3                         3144.0               1.620000e+12       199452.0
# 4                        42597.0               1.620000e+12       360833.0
# 5                         1237.0               1.620000e+12       199452.0
# 6                         2632.0               1.620000e+12       199452.0
# 7                         5931.0               1.620000e+12       199414.0
# 8                        14810.0               1.620000e+12            0.0
# 9                         8901.0               1.620000e+12       199452.0
#
#    uuidSource_cr stateGrpDimId_cr  cityGrpDimId_cr  conversion_fraud
# 0            1.0         348022.0         348007.0              True
# 1            1.0         348024.0         348010.0              True
# 2            1.0         348027.0         348005.0              True
# 3            1.0         348023.0         348007.0              True
# 4            1.0         348025.0         348007.0              True
# 5            1.0         348024.0         348010.0              True
# 6            1.0         348023.0         348007.0              True
# 7            1.0         348024.0         348005.0              True
# 8            1.0         348022.0         348007.0              True
# 9            1.0         348023.0         348007.0              True
#
# [10 rows x 35 columns]

# %% [markdown]
# #### There are still more catogorical features which we have to handle

# %% [markdown]
# refurl_cr ,   connTypeDvimId_cr  ,   allAudiences_cr

# %%
len(train_df['refurl_cr'].unique())
# Out:
# 399

# %%
train_df['refurl_cr']
# Out:
# 0      https%3A%2F%2Fwww.timesjobs.com%2Fcandidate%2F...
# 1      https%3A%2F%2Fwww.cricbuzz.com%2Flive-cricket-...
# 2      https%3A%2F%2Fwww.timesjobs.com%2Fcandidate%2F...
# 3      https%3A%2F%2Fwww.timesjobs.com%2Fcandidate%2F...
# 4      https%3A%2F%2Ftelugu.samayam.com%2Fvideo-galle...
#                              ...
# 960        http%3A%2F%2Fnavbharattimes.indiatimes.com%2F
# 961          http%3A%2F%2Ftimesofindia.indiatimes.com%2F
# 962    https%3A%2F%2Fwww.sakshieducation.com%2FPrevio...
# 963                          https%3A%2F%2Fwww.olx.in%2F
# 964                          https%3A%2F%2Fwww.olx.in%2F
# Name: refurl_cr, Length: 965, dtype: object

# %%
len(train_df['connTypeDimId_cr'].unique())
# Out:
# 9

# %%
train_df['connTypeDimId_cr']
# Out:
# 0      264496
# 1      264496
# 2      264503
# 3      264496
# 4      264496
#         ...
# 960    264494
# 961    264496
# 962    264496
# 963    264494
# 964    264496
# Name: connTypeDimId_cr, Length: 965, dtype: object

# %% [markdown]
# This feature 'connTypeDimId_cr' is a numeric catogorical feature

# %%
train_df['refurl_cr'][1]
# Out:
# 'https%3A%2F%2Fwww.cricbuzz.com%2Flive-cricket-scores%2F32278%2Find-vs-eng-4th-t20i-england-tour-of-india-2021'

# %%
train_df['allAudiences_cr']
# Out:
# 0      7dn,6hs,35g,ome,omf,l32,nqo,2ws,qqo,lo4,oos,2w...
# 1      h9r,35j,7dx,592,lo4,5o2,gau,75y,k8l,2ve,k8p,8k...
# 2      7dn,oy7,nqo,41j,2ws,lo4,oos,oou,apc,5o2,o6b,ox...
# 3      p1b,7dn,6hs,jyq,35g,h98,oul,nqo,2ws,lo4,p12,2w...
# 4                                                761,75y
#                              ...
# 960    7dm,jyq,8h4,k1m,nyw,lo4,nqv,o1w,o1v,apc,o1y,o1...
# 961    jyq,ige,33h,41f,mss,oy7,nyw,oy9,lo4,ii1,nqx,o1...
# 962                                                  9nj
# 963                                          hkf,9nj,5xq
# 964                                          hkf,9nj,5xq
# Name: allAudiences_cr, Length: 965, dtype: object

# %%
len(train_df['allAudiences_cr'].unique())
# Out:
# 820

# %% [markdown]
# #### Again We need to drop these unwanted features

# %%
cols_not_needed = ['refurl_cr', 'allAudiences_cr']

# %%
train_df.drop(cols_not_needed, axis="columns", inplace=True)

# %% [markdown]
# We need to convert the feature 'connTypeDimId_cr' from object to float

# %%
train_df['connTypeDimId_cr'] = pd.to_numeric(train_df['connTypeDimId_cr'], errors='coerce')

# %% [markdown]
# Seems this feature 'connTypeDimId_cr' is having few missing values let's fill it

# %%
train_df['connTypeDimId_cr'].isnull().mean()*100
# Out:
# 0.7253886010362695

# %%
train_df.dtypes
# Out:
# clientid_cr                        int64
# conversiontime_cr                float64
# adslotdimid_cr                     int64
# algo_cr                          float64
# clickbid_cr                      float64
# geodimid_cr                        int64
# itemcolumbiaid_cr                  int64
# itemid_cr                          int64
# position_cr                      float64
# pubclientid_cr                     int64
# siteId_cr                          int64
# templateid_cr                    float64
# goalid_cr                          int64
# time_cr                          float64
# adLogType_cr                       int64
# v_cr                             float64
# pricingtype_cr                     int64
# osId_cr                          float64
# browserId_cr                     float64
# cityId_cr                        float64
# stateId_cr                       float64
# modelDimId_cr                    float64
# connTypeDimId_cr                 float64
# ispDimId_cr                      float64
# countryDimId_cr                  float64
# goalTypeId_cr                      int64
# conversionDurationInMillis_cr    float64
# impressionTimeInMillis_cr        float64
# osVerDimId_cr                    float64
# uuidSource_cr                    float64
# stateGrpDimId_cr                 float64
# cityGrpDimId_cr                  float64
# conversion_fraud                    bool
# dtype: object

# %% [markdown]
# #### Seems that the feature connTypeDimId_cr has few missing values

# %%
train_df[pd.to_numeric(train_df.connTypeDimId_cr,errors='coerce').isnull()==True]
# Out:
#      clientid_cr  conversiontime_cr  adslotdimid_cr  algo_cr  clickbid_cr  \
# 203        29892       1.620000e+12          334766     33.0         2.79
# 309        25470       1.620000e+12          236059      2.0         2.79
# 422         2139       1.620000e+12          195755     18.0        10.00
# 630        31365       1.620000e+12          195755     18.0         0.90
# 676        25470       1.620000e+12          355148     38.0         2.79
# 681        31365       1.620000e+12          334762     18.0         2.79
# 774        29892       1.620000e+12          355148     18.0         2.79
#
#      geodimid_cr  itemcolumbiaid_cr  itemid_cr  position_cr  pubclientid_cr  \
# 203          433            5592344   53924039          1.0           76969
# 309          144            5617958   53924418         10.0           15240
# 422          144            5610374   53184763          2.0            7268
# 630          144            5616679   53930184          2.0            7268
# 676          144            5614752   53924415          1.0            2316
# 681          144            5616679   53930182          1.0           76969
# 774          144            5583264   53924038          1.0            2316
#
#      ...  ispDimId_cr  countryDimId_cr  goalTypeId_cr  \
# 203  ...          0.0            433.0             10
# 309  ...     136127.0            144.0             10
# 422  ...     136127.0            144.0             10
# 630  ...     280429.0            144.0             10
# 676  ...     280429.0            144.0             10
# 681  ...     280429.0            144.0             10
# 774  ...     147211.0            144.0             10
#
#      conversionDurationInMillis_cr  impressionTimeInMillis_cr  osVerDimId_cr  \
# 203                      3670493.0               1.620000e+12       360833.0
# 309                     19311004.0               1.620000e+12       360833.0
# 422                       684436.0               1.620000e+12       359921.0
# 630                     13152725.0               1.620000e+12       360833.0
# 676                     44955769.0               1.620000e+12       359921.0
# 681                     13239231.0               1.620000e+12       359921.0
# 774                      2146992.0               1.620000e+12       359921.0
#
#      uuidSource_cr  stateGrpDimId_cr  cityGrpDimId_cr  conversion_fraud
# 203            3.0          348021.0         348009.0             False
# 309            3.0          348023.0         348007.0             False
# 422            3.0          348020.0         348006.0             False
# 630            3.0          348020.0         348006.0             False
# 676            3.0          348026.0         348008.0             False
# 681            3.0          348020.0         348006.0             False
# 774            3.0          348022.0         348007.0             False
#
# [7 rows x 33 columns]

# %%
len(train_df[pd.to_numeric(train_df.connTypeDimId_cr,errors='coerce').isnull()==True])
# Out:
# 7

# %%
impute_nan(train_df, 'connTypeDimId_cr')

# %%
train_df['connTypeDimId_cr'].isnull().mean()
# Out:
# 0.0

# %%
train_df.dtypes
# Out:
# clientid_cr                        int64
# conversiontime_cr                float64
# adslotdimid_cr                     int64
# algo_cr                          float64
# clickbid_cr                      float64
# geodimid_cr                        int64
# itemcolumbiaid_cr                  int64
# itemid_cr                          int64
# position_cr                      float64
# pubclientid_cr                     int64
# siteId_cr                          int64
# templateid_cr                    float64
# goalid_cr                          int64
# time_cr                          float64
# adLogType_cr                       int64
# v_cr                             float64
# pricingtype_cr                     int64
# osId_cr                          float64
# browserId_cr                     float64
# cityId_cr                        float64
# stateId_cr                       float64
# modelDimId_cr                    float64
# connTypeDimId_cr                 float64
# ispDimId_cr                      float64
# countryDimId_cr                  float64
# goalTypeId_cr                      int64
# conversionDurationInMillis_cr    float64
# impressionTimeInMillis_cr        float64
# osVerDimId_cr                    float64
# uuidSource_cr                    float64
# stateGrpDimId_cr                 float64
# cityGrpDimId_cr                  float64
# conversion_fraud                    bool
# dtype: object

# %%
train_df['connTypeDimId_cr'].dtypes
# Out:
# dtype('float64')

# %% [markdown]
# ### Feature Scaling

# %%
cols_to_scale = [feature for feature in train_df.columns if feature != 'conversion_fraud']

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
train_df[cols_to_scale] = scaler.fit_transform(train_df[cols_to_scale])

# %%
train_df.head()
# Out:
#    clientid_cr  conversiontime_cr  adslotdimid_cr   algo_cr  clickbid_cr  \
# 0     0.873346                0.0        0.830089  0.001423      0.09359
# 1     0.873346                0.0        0.000527  0.001423      0.08982
# 2     0.873346                0.0        0.831186  0.000769      0.08982
# 3     0.873346                0.0        0.830089  0.001423      0.08982
# 4     0.345516                0.0        0.978965  0.000769      0.08982
#
#    geodimid_cr  itemcolumbiaid_cr  itemid_cr   position_cr  pubclientid_cr  \
# 0          0.0           0.944360   0.867568  1.225933e-09        0.027273
# 1          0.0           0.944648   0.867568  1.225933e-09        0.179221
# 2          0.0           0.944360   0.867568  1.225933e-09        0.027273
# 3          0.0           0.944360   0.867568  1.225933e-09        0.027273
# 4          0.0           0.997236   0.990331  1.225933e-09        0.000000
#
#    ...  ispDimId_cr  countryDimId_cr  goalTypeId_cr  \
# 0  ...     0.979856              0.0            0.0
# 1  ...     0.475646              0.0            0.0
# 2  ...     0.603524              0.0            0.0
# 3  ...     0.475646              0.0            0.0
# 4  ...     0.475646              0.0            0.0
#
#    conversionDurationInMillis_cr  impressionTimeInMillis_cr  osVerDimId_cr  \
# 0                   8.463155e-07                        1.0       0.551815
# 1                   1.191272e-06                        1.0       0.551815
# 2                   1.040428e-06                        1.0       0.551815
# 3                   1.168646e-06                        1.0       0.551815
# 4                   1.682985e-05                        1.0       0.998301
#
#    uuidSource_cr  stateGrpDimId_cr  cityGrpDimId_cr  conversion_fraud
# 0            0.0          0.285714              0.4              True
# 1            0.0          0.571429              1.0              True
# 2            0.0          1.000000              0.0              True
# 3            0.0          0.428571              0.4              True
# 4            0.0          0.714286              0.4              True
#
# [5 rows x 33 columns]

# %%
train_df['conversion_fraud'].value_counts()
# Out:
# False    834
# True     131
# Name: conversion_fraud, dtype: int64

# %%
sns.set_theme(style="darkgrid")
sns.countplot(train_df['conversion_fraud'], palette='Set1')
plt.xlabel('conversion_fraud', size = 15)
plt.show()
# Out:
# C:\Users\Sudharsan Baskar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### Seems our dataset is imbalanced

# %%
train_df['conversion_fraud'].replace({True:1, False:0}, inplace=True)

# %%
X = train_df.drop('conversion_fraud', axis="columns")
y = train_df['conversion_fraud']

# %% [markdown]
# #### Balancing the dataset

# %%
from imblearn.combine import SMOTETomek
smk = SMOTETomek(random_state=42)
X,y = smk.fit_resample(X, y)

# %%
sns.set_theme(style="darkgrid")
sns.countplot(y, palette='Set1')
plt.xlabel('conversion_fraud', size = 15)
plt.show()
# Out:
# C:\Users\Sudharsan Baskar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ##### Now our dataset is balanced

# %% [markdown]
# ### Train test split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=5)

# %%
X_train
# Out:
#       clientid_cr  conversiontime_cr  adslotdimid_cr   algo_cr  clickbid_cr  \
# 1379     0.345516                0.0        0.978965  0.000769     0.103335
# 1407     0.873346                0.0        0.838054  0.001459     0.103732
# 446      0.743834                0.0        0.978965  0.000769     0.104553
# 1582     0.752560                0.0        0.771047  0.001443     0.086516
# 1485     0.948305                0.0        0.450991  0.000769     0.004752
# ...           ...                ...             ...       ...          ...
# 1424     0.873346                0.0        0.832349  0.001461     0.101470
# 1142     0.873346                0.0        0.830089  0.001423     0.102235
# 998      0.873346                0.0        0.830089  0.001423     0.104553
# 206      0.743834                0.0        0.978965  0.000769     0.470488
# 867      0.873346                0.0        0.879687  0.001423     0.089820
#
#       geodimid_cr  itemcolumbiaid_cr  itemid_cr   position_cr  pubclientid_cr  \
# 1379     0.000000           0.997236   0.990331  1.225933e-09        0.000000
# 1407     0.000000           0.944376   0.867568  7.891488e-03        0.027495
# 446      0.000000           0.992129   0.977614  1.225933e-09        0.000000
# 1582     0.000000           0.953364   0.891540  7.569145e-02        0.059171
# 1485     0.000003           0.960550   0.818499  2.309396e-09        0.031248
# ...           ...                ...        ...           ...             ...
# 1424     0.000000           0.944360   0.867568  1.225933e-09        0.027273
# 1142     0.000000           0.944360   0.867568  1.225933e-09        0.027273
# 998      0.000000           0.944360   0.867568  1.322938e-09        0.027273
# 206      0.000000           0.999150   0.999995  1.225933e-09        0.000000
# 867      0.000000           0.944648   0.867568  2.225539e-01        0.031248
#
#       ...  connTypeDimId_cr  ispDimId_cr  countryDimId_cr  goalTypeId_cr  \
# 1379  ...          0.222222     0.475646         0.000000            0.0
# 1407  ...          1.000000     0.932630         0.000000            0.0
# 446   ...          1.000000     0.475646         0.000000            0.0
# 1582  ...          0.137971     0.517380         0.000000            0.0
# 1485  ...          0.000000     0.948872         0.003448            0.0
# ...   ...               ...          ...              ...            ...
# 1424  ...          0.000000     0.482969         0.000000            0.0
# 1142  ...          0.046978     0.942129         0.000000            0.0
# 998   ...          0.000000     0.932558         0.000000            0.0
# 206   ...          0.222222     0.979856         0.000000            0.0
# 867   ...          1.000000     0.932630         0.000000            0.0
#
#       conversionDurationInMillis_cr  impressionTimeInMillis_cr  osVerDimId_cr  \
# 1379                   1.026959e-05                        1.0       0.998301
# 1407                   7.270443e-07                        1.0       0.551716
# 446                    7.268970e-01                        0.0       0.551815
# 1582                   2.613794e-05                        1.0       0.556162
# 1485                   3.764555e-06                        1.0       0.000000
# ...                             ...                        ...            ...
# 1424                   1.163619e-06                        1.0       0.551732
# 1142                   1.097687e-06                        1.0       0.551732
# 998                    6.705531e-07                        1.0       0.552009
# 206                    1.802509e-05                        1.0       0.995778
# 867                    1.852208e-06                        1.0       0.551815
#
#       uuidSource_cr  stateGrpDimId_cr  cityGrpDimId_cr
# 1379            0.0          0.714286         0.766925
# 1407            0.0          0.277752         0.377707
# 446             0.0          0.142857         0.000000
# 1582            0.0          0.428571         0.600000
# 1485            0.0          0.411969         0.576757
# ...             ...               ...              ...
# 1424            0.0          0.970103         0.000000
# 1142            0.0          0.285714         0.400000
# 998             0.0          0.417267         0.400000
# 206             0.0          0.571429         1.000000
# 867             0.0          0.142857         0.000000
#
# [1326 rows x 32 columns]

# %%
X.shape
# Out:
# (1658, 32)

# %% [markdown]
# ### Training with Neural Network

# %%
from tensorflow import keras
import tensorflow as tf

# %%
print(tf.test.is_gpu_available())
# Out:
# True

# %%
model = keras.Sequential([
    keras.layers.Dense(32, input_shape=(32,), activation='relu'),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer = 'adam',
             loss = 'binary_crossentropy',
             metrics = ['accuracy'])

model.fit(X_train, y_train, epochs = 100)
# Out:
# Epoch 1/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.6864 - accuracy: 0.5543
# Epoch 2/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.6634 - accuracy: 0.6637
# Epoch 3/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.6403 - accuracy: 0.6576
# Epoch 4/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.6144 - accuracy: 0.6629
# Epoch 5/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.5970 - accuracy: 0.6750
# Epoch 6/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.5810 - accuracy: 0.6810
# Epoch 7/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.5657 - accuracy: 0.6938
# Epoch 8/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.5539 - accuracy: 0.7006
# Epoch 9/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.5402 - accuracy: 0.7149
# Epoch 10/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.5344 - accuracy: 0.7217
# Epoch 11/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.5206 - accuracy: 0.7338
# Epoch 12/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.5194 - accuracy: 0.7368
# Epoch 13/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.5140 - accuracy: 0.7451
# Epoch 14/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.5052 - accuracy: 0.7511
# Epoch 15/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.4936 - accuracy: 0.7609
# Epoch 16/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.4879 - accuracy: 0.7722
# Epoch 17/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.4814 - accuracy: 0.7738
# Epoch 18/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.4819 - accuracy: 0.7677
# Epoch 19/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.4741 - accuracy: 0.7647
# Epoch 20/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.4687 - accuracy: 0.7745
# Epoch 21/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.4607 - accuracy: 0.7896
# Epoch 22/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.4582 - accuracy: 0.7768
# Epoch 23/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.4605 - accuracy: 0.7775
# Epoch 24/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.4462 - accuracy: 0.7881
# Epoch 25/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.4366 - accuracy: 0.7873
# Epoch 26/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.4393 - accuracy: 0.7926
# Epoch 27/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.4334 - accuracy: 0.7986
# Epoch 28/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.4264 - accuracy: 0.7926
# Epoch 29/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.4385 - accuracy: 0.7926
# Epoch 30/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.4172 - accuracy: 0.7979
# Epoch 31/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.4122 - accuracy: 0.8039
# Epoch 32/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.4058 - accuracy: 0.8054
# Epoch 33/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.4018 - accuracy: 0.8054
# Epoch 34/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.3993 - accuracy: 0.8100
# Epoch 35/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.4022 - accuracy: 0.8054
# Epoch 36/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.3944 - accuracy: 0.8145
# Epoch 37/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.3976 - accuracy: 0.8115
# Epoch 38/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.3812 - accuracy: 0.8281
# Epoch 39/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.3831 - accuracy: 0.8213
# Epoch 40/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.3848 - accuracy: 0.8235
# Epoch 41/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.3708 - accuracy: 0.8265
# Epoch 42/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.3700 - accuracy: 0.8220
# Epoch 43/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3647 - accuracy: 0.8303
# Epoch 44/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3687 - accuracy: 0.8363
# Epoch 45/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.3616 - accuracy: 0.8281
# Epoch 46/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.3630 - accuracy: 0.8296
# Epoch 47/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.3538 - accuracy: 0.8333
# Epoch 48/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.3493 - accuracy: 0.8416
# Epoch 49/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.3423 - accuracy: 0.8462
# Epoch 50/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.3505 - accuracy: 0.8446
# Epoch 51/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.3510 - accuracy: 0.8401
# Epoch 52/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.3409 - accuracy: 0.8439
# Epoch 53/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.3356 - accuracy: 0.8492
# Epoch 54/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.3394 - accuracy: 0.8492
# Epoch 55/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.3272 - accuracy: 0.8567
# Epoch 56/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.3248 - accuracy: 0.8620
# Epoch 57/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.3193 - accuracy: 0.8597
# Epoch 58/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3200 - accuracy: 0.8665
# Epoch 59/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.3253 - accuracy: 0.8590
# Epoch 60/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.3141 - accuracy: 0.8650
# Epoch 61/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.3124 - accuracy: 0.8703
# Epoch 62/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.3129 - accuracy: 0.8612
# Epoch 63/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.3058 - accuracy: 0.8703
# Epoch 64/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.3039 - accuracy: 0.8771
# Epoch 65/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.3091 - accuracy: 0.8650
# Epoch 66/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.3060 - accuracy: 0.8635
# Epoch 67/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.3123 - accuracy: 0.8620
# Epoch 68/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2923 - accuracy: 0.8763
# Epoch 69/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.3034 - accuracy: 0.8839
# Epoch 70/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.3012 - accuracy: 0.8673
# Epoch 71/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2970 - accuracy: 0.8680
# Epoch 72/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2987 - accuracy: 0.8748
# Epoch 73/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2880 - accuracy: 0.8771
# Epoch 74/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2845 - accuracy: 0.8801
# Epoch 75/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2854 - accuracy: 0.8808
# Epoch 76/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2915 - accuracy: 0.8808
# Epoch 77/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2914 - accuracy: 0.8703
# Epoch 78/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2868 - accuracy: 0.8756
# Epoch 79/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.2819 - accuracy: 0.8793
# Epoch 80/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2832 - accuracy: 0.8756
# Epoch 81/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2783 - accuracy: 0.8854
# Epoch 82/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2860 - accuracy: 0.8846
# Epoch 83/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2764 - accuracy: 0.8786
# Epoch 84/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2904 - accuracy: 0.8725
# Epoch 85/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2737 - accuracy: 0.8801
# Epoch 86/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2729 - accuracy: 0.8771
# Epoch 87/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2695 - accuracy: 0.8846
# Epoch 88/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2677 - accuracy: 0.8937
# Epoch 89/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2650 - accuracy: 0.8869
# Epoch 90/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2690 - accuracy: 0.8786
# Epoch 91/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2650 - accuracy: 0.8884
# Epoch 92/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2610 - accuracy: 0.8914
# Epoch 93/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2604 - accuracy: 0.8884
# Epoch 94/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2560 - accuracy: 0.8974
# Epoch 95/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2571 - accuracy: 0.8937
# Epoch 96/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2584 - accuracy: 0.8922
# Epoch 97/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2594 - accuracy: 0.8937
# Epoch 98/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2553 - accuracy: 0.8944
# Epoch 99/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2513 - accuracy: 0.8959
# Epoch 100/100
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2628 - accuracy: 0.8891

# %%
model.evaluate(X_test, y_test)
# Out:
# 11/11 [==============================] - 0s 1ms/step - loss: 0.2940 - accuracy: 0.8645
# [0.2940155863761902, 0.8644578456878662]

# %% [markdown]
# ## Hyper Parameter Tuning for Machine Learning algorithms

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression

# %%
lr_score = cross_val_score(LogisticRegression(), X, y, cv=10)
lr_score.mean()
# Out:
# C:\Users\Sudharsan Baskar\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Sudharsan Baskar\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Sudharsan Baskar\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Sudharsan Baskar\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7087039065352319

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
clf = GridSearchCV(DecisionTreeClassifier(), {'criterion':['gini', 'entropy']}, cv=10, return_train_score=False)
clf.fit(X, y)
clf.cv_results_
# Out:
# {'mean_fit_time': array([0.00862925, 0.00957932]),
#  'std_fit_time': array([0.00089781, 0.00047368]),
#  'mean_score_time': array([0.0012964 , 0.00149546]),
#  'std_score_time': array([0.0004575, 0.0004983]),
#  'param_criterion': masked_array(data=['gini', 'entropy'],
#               mask=[False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'criterion': 'gini'}, {'criterion': 'entropy'}],
#  'split0_test_score': array([0.87951807, 0.88554217]),
#  'split1_test_score': array([0.87951807, 0.86746988]),
#  'split2_test_score': array([0.95180723, 0.92771084]),
#  'split3_test_score': array([0.95783133, 0.94578313]),
#  'split4_test_score': array([0.87349398, 0.93975904]),
#  'split5_test_score': array([0.93373494, 0.94578313]),
#  'split6_test_score': array([0.93975904, 0.95180723]),
#  'split7_test_score': array([0.92771084, 0.95783133]),
#  'split8_test_score': array([0.95757576, 0.93939394]),
#  'split9_test_score': array([0.93939394, 0.96363636]),
#  'mean_test_score': array([0.92403432, 0.93247171]),
#  'std_test_score': array([0.03185455, 0.02982265]),
#  'rank_test_score': array([2, 1])}

# %%
dt_result_df = pd.DataFrame(clf.cv_results_)
dt_result_df[['param_criterion', 'mean_test_score']]
# Out:
#   param_criterion  mean_test_score
# 0            gini         0.924034
# 1         entropy         0.932472

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf_clf = GridSearchCV(RandomForestClassifier(), {'n_estimators':[1, 5, 10, 20, 40, 50,60]}, cv=10, return_train_score=False)
rf_clf.fit(X, y)
rf_clf.cv_results_
# Out:
# {'mean_fit_time': array([0.00398927, 0.0107312 , 0.01940925, 0.03608885, 0.07173157,
#         0.08761215, 0.10667186]),
#  'std_fit_time': array([0.00044574, 0.00040627, 0.00056945, 0.00072446, 0.00155387,
#         0.00094319, 0.00239219]),
#  'mean_score_time': array([0.00169559, 0.00199344, 0.00239332, 0.00318351, 0.00461702,
#         0.00571613, 0.00659926]),
#  'std_score_time': array([4.57288212e-04, 1.35069754e-05, 4.89191666e-04, 3.92549818e-04,
#         4.63612916e-04, 4.26874252e-04, 4.34051327e-04]),
#  'param_n_estimators': masked_array(data=[1, 5, 10, 20, 40, 50, 60],
#               mask=[False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'n_estimators': 1},
#   {'n_estimators': 5},
#   {'n_estimators': 10},
#   {'n_estimators': 20},
#   {'n_estimators': 40},
#   {'n_estimators': 50},
#   {'n_estimators': 60}],
#  'split0_test_score': array([0.90963855, 0.89156627, 0.90963855, 0.90361446, 0.93373494,
#         0.91566265, 0.90963855]),
#  'split1_test_score': array([0.8373494 , 0.90361446, 0.89156627, 0.91566265, 0.90361446,
#         0.90963855, 0.89156627]),
#  'split2_test_score': array([0.89759036, 0.98795181, 0.98192771, 0.98192771, 0.98795181,
#         0.9939759 , 0.9939759 ]),
#  'split3_test_score': array([0.90361446, 0.96385542, 0.96385542, 0.97590361, 0.9939759 ,
#         0.97590361, 0.98192771]),
#  'split4_test_score': array([0.87951807, 0.95783133, 0.9939759 , 0.97590361, 0.9939759 ,
#         0.9939759 , 0.98795181]),
#  'split5_test_score': array([0.92771084, 0.94578313, 0.97590361, 0.96987952, 0.98192771,
#         0.97590361, 0.96987952]),
#  'split6_test_score': array([0.89759036, 0.95783133, 0.97590361, 0.96385542, 0.96385542,
#         0.97590361, 0.97590361]),
#  'split7_test_score': array([0.88554217, 0.93373494, 0.95783133, 0.97590361, 0.96987952,
#         0.96987952, 0.96987952]),
#  'split8_test_score': array([0.92727273, 0.96969697, 0.96363636, 0.98181818, 0.98787879,
#         0.98181818, 0.98787879]),
#  'split9_test_score': array([0.87272727, 0.97575758, 0.96969697, 0.96969697, 0.99393939,
#         0.98787879, 0.99393939]),
#  'mean_test_score': array([0.89385542, 0.94876232, 0.95839357, 0.96141658, 0.97107338,
#         0.96805403, 0.96625411]),
#  'std_test_score': array([0.02559131, 0.02939308, 0.03075956, 0.02654656, 0.02873224,
#         0.02876068, 0.03409112]),
#  'rank_test_score': array([7, 6, 5, 4, 1, 2, 3])}

# %%
rf_result_df = pd.DataFrame(rf_clf.cv_results_)
rf_result_df[['param_n_estimators', 'mean_test_score']]
# Out:
#   param_n_estimators  mean_test_score
# 0                  1         0.893855
# 1                  5         0.948762
# 2                 10         0.958394
# 3                 20         0.961417
# 4                 40         0.971073
# 5                 50         0.968054
# 6                 60         0.966254

# %% [markdown]
# ### Support Vector Machine(SVM)

# %%
from sklearn.svm import SVC
svm_clf = GridSearchCV(SVC(), {'C': [1,10,20], 'kernel': ['rbf','linear']}, cv=10, return_train_score=False)
svm_clf.fit(X, y)
svm_clf.cv_results_
# Out:
# {'mean_fit_time': array([0.05252802, 0.04126208, 0.04782574, 0.08820596, 0.04796691,
#         0.13650835]),
#  'std_fit_time': array([0.00171965, 0.00175318, 0.00098243, 0.01150766, 0.00114834,
#         0.01864573]),
#  'mean_score_time': array([0.01375866, 0.00409365, 0.01129239, 0.00399153, 0.00993581,
#         0.00388904]),
#  'std_score_time': array([5.97791368e-04, 2.97842791e-04, 6.26734598e-04, 4.10474820e-06,
#         4.56402000e-04, 2.85073952e-04]),
#  'param_C': masked_array(data=[1, 1, 10, 10, 20, 20],
#               mask=[False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_kernel': masked_array(data=['rbf', 'linear', 'rbf', 'linear', 'rbf', 'linear'],
#               mask=[False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'C': 1, 'kernel': 'rbf'},
#   {'C': 1, 'kernel': 'linear'},
#   {'C': 10, 'kernel': 'rbf'},
#   {'C': 10, 'kernel': 'linear'},
#   {'C': 20, 'kernel': 'rbf'},
#   {'C': 20, 'kernel': 'linear'}],
#  'split0_test_score': array([0.77108434, 0.69277108, 0.81927711, 0.71686747, 0.81325301,
#         0.71084337]),
#  'split1_test_score': array([0.74698795, 0.69277108, 0.81927711, 0.69277108, 0.81927711,
#         0.69277108]),
#  'split2_test_score': array([0.80120482, 0.75301205, 0.84337349, 0.73493976, 0.84939759,
#         0.73493976]),
#  'split3_test_score': array([0.72289157, 0.70481928, 0.78313253, 0.70481928, 0.81325301,
#         0.70481928]),
#  'split4_test_score': array([0.77710843, 0.62650602, 0.88554217, 0.62048193, 0.89156627,
#         0.62048193]),
#  'split5_test_score': array([0.74698795, 0.69879518, 0.81325301, 0.69277108, 0.81927711,
#         0.69277108]),
#  'split6_test_score': array([0.75903614, 0.6686747 , 0.87951807, 0.71084337, 0.89156627,
#         0.69879518]),
#  'split7_test_score': array([0.77108434, 0.74698795, 0.86746988, 0.73493976, 0.87951807,
#         0.74096386]),
#  'split8_test_score': array([0.73333333, 0.7030303 , 0.83030303, 0.73333333, 0.86060606,
#         0.73333333]),
#  'split9_test_score': array([0.78181818, 0.72727273, 0.85454545, 0.73333333, 0.86666667,
#         0.73939394]),
#  'mean_test_score': array([0.76115371, 0.70146404, 0.83956919, 0.70751004, 0.85043812,
#         0.70691128]),
#  'std_test_score': array([0.02264219, 0.03501646, 0.03084424, 0.03309493, 0.03050247,
#         0.03413803]),
#  'rank_test_score': array([3, 6, 2, 4, 1, 5])}

# %%
svm_result_df = pd.DataFrame(svm_clf.cv_results_)
svm_result_df[['param_C', 'param_kernel', 'mean_test_score']]
# Out:
#   param_C param_kernel  mean_test_score
# 0       1          rbf         0.761154
# 1       1       linear         0.701464
# 2      10          rbf         0.839569
# 3      10       linear         0.707510
# 4      20          rbf         0.850438
# 5      20       linear         0.706911

# %% [markdown]
# ### Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
nb_clf = GridSearchCV(GaussianNB(),{}, cv=10, return_train_score=False)
nb_clf.fit(X, y)
nb_clf.cv_results_
# Out:
# {'mean_fit_time': array([0.00219407]),
#  'std_fit_time': array([0.00039904]),
#  'mean_score_time': array([0.00129666]),
#  'std_score_time': array([0.00045707]),
#  'params': [{}],
#  'split0_test_score': array([0.61445783]),
#  'split1_test_score': array([0.57228916]),
#  'split2_test_score': array([0.62048193]),
#  'split3_test_score': array([0.63855422]),
#  'split4_test_score': array([0.59638554]),
#  'split5_test_score': array([0.58433735]),
#  'split6_test_score': array([0.59638554]),
#  'split7_test_score': array([0.57228916]),
#  'split8_test_score': array([0.61212121]),
#  'split9_test_score': array([0.63030303]),
#  'mean_test_score': array([0.6037605]),
#  'std_test_score': array([0.02201358]),
#  'rank_test_score': array([1])}

# %%
nb_result_df = pd.DataFrame(nb_clf.cv_results_)
nb_result_df[['mean_test_score']]
# Out:
#    mean_test_score
# 0          0.60376

# %% [markdown]
# #### We can infer that the performance of Random forest and Decision tree are good.So we will be using it for the final prediction

# %% [markdown]
# ### Preprocessing the Test data

# %%
test_df.head()
# Out:
#    record_id  clientid_cr                               clmbuserid_cr  \
# 0       1000        82122   1045e8b8-662e-49b3-bc4a-4af5326c8236-62kw
# 1       1001        75694  53a9a707-967d-4a67-8e9f-e3dd55b464e8-10wm0
# 2       1002        75694  53a9a707-967d-4a67-8e9f-e3dd55b464e8-10wm0
# 3       1003        30431  5febd7e2-b66a-4af0-91ec-117557684188-10wrk
# 4       1004        30431  5febd7e2-b66a-4af0-91ec-117557684188-10wrk
#
#    conversiontime_cr                                   imprid_cr  \
# 0      1620000000000  864cdaf0-cca7-4bcc-b210-a33858cf8755-1siz8
# 1      1620000000000  6c44c171-9445-4e6b-856e-89bfcd0be22c-1sito
# 2      1620000000000  c00eae97-46c5-48b8-89bf-9d45628b9de3-1siz8
# 3      1620000000000  40aad66c-d2da-4635-8b5e-46aca58d2dc6-10o78
# 4      1620000000000  4742d072-32ed-45bc-9ca9-5dca4a69f5b1-10onw
#
#    adslotdimid_cr  algo_cr audiences_cr  clickbid_cr  geodimid_cr  ...  \
# 0          233531       38          NaN          NaN          145  ...
# 1          356952       20          NaN          3.1          144  ...
# 2          356952       18          NaN          3.1          144  ...
# 3          355768       21          NaN          NaN          144  ...
# 4          355768       21          NaN          NaN          144  ...
#
#   usrClusterId_cr  cityGrpDimId_cr  siteClusterIds_cr  refClusterId_cr  \
# 0             NaN              NaN       3.337341e+17              NaN
# 1             NaN         348006.0                NaN              NaN
# 2             NaN         348006.0                NaN              NaN
# 3             NaN         348010.0                NaN              NaN
# 4             NaN         348010.0                NaN              NaN
#
#    paid_cr spend_cr  attributionType_cr  conversionid_cr  optimize_on_cr  \
# 0      NaN      NaN                 NaN              NaN             NaN
# 1      NaN      NaN                 NaN              NaN             NaN
# 2      NaN      NaN                 NaN              NaN             NaN
# 3      1.0    275.0                 1.0              NaN             NaN
# 4      1.0    275.0                 1.0              NaN             NaN
#
#    bundleId_cr
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 56 columns]

# %%
test_record_id = test_df['record_id']

# %%
cols_needed = list(X.columns)

# %%
len(cols_needed)
# Out:
# 32

# %%
cols_needed
# Out:
# ['clientid_cr',
#  'conversiontime_cr',
#  'adslotdimid_cr',
#  'algo_cr',
#  'clickbid_cr',
#  'geodimid_cr',
#  'itemcolumbiaid_cr',
#  'itemid_cr',
#  'position_cr',
#  'pubclientid_cr',
#  'siteId_cr',
#  'templateid_cr',
#  'goalid_cr',
#  'time_cr',
#  'adLogType_cr',
#  'v_cr',
#  'pricingtype_cr',
#  'osId_cr',
#  'browserId_cr',
#  'cityId_cr',
#  'stateId_cr',
#  'modelDimId_cr',
#  'connTypeDimId_cr',
#  'ispDimId_cr',
#  'countryDimId_cr',
#  'goalTypeId_cr',
#  'conversionDurationInMillis_cr',
#  'impressionTimeInMillis_cr',
#  'osVerDimId_cr',
#  'uuidSource_cr',
#  'stateGrpDimId_cr',
#  'cityGrpDimId_cr']

# %%
test_df_1 = test_df[cols_needed]

# %%
test_df_1.head()
# Out:
#    clientid_cr  conversiontime_cr  adslotdimid_cr  algo_cr  clickbid_cr  \
# 0        82122      1620000000000          233531       38          NaN
# 1        75694      1620000000000          356952       20          3.1
# 2        75694      1620000000000          356952       18          3.1
# 3        30431      1620000000000          355768       21          NaN
# 4        30431      1620000000000          355768       21          NaN
#
#    geodimid_cr  itemcolumbiaid_cr  itemid_cr  position_cr  pubclientid_cr  \
# 0          145            5526656   53184285            3            2658
# 1          144            5488773   49504162            1           85030
# 2          144            5488088   49504161            1           85030
# 3          144            5614054   53607445            1               1
# 4          144            5614054   53607445            1               1
#
#    ...  connTypeDimId_cr  ispDimId_cr  countryDimId_cr  goalTypeId_cr  \
# 0  ...            264494       265618              145             10
# 1  ...            264496       280429              144             10
# 2  ...            264496       280429              144             10
# 3  ...            264496       280429              144             10
# 4  ...            264496       280429              144             10
#
#    conversionDurationInMillis_cr  impressionTimeInMillis_cr  osVerDimId_cr  \
# 0                         369206              1620000000000              0
# 1                           2298              1620000000000         199414
# 2                           5713              1620000000000         199414
# 3                          66670              1620000000000         360833
# 4                          53789              1620000000000         360833
#
#    uuidSource_cr  stateGrpDimId_cr  cityGrpDimId_cr
# 0              1               NaN              NaN
# 1              1          348020.0         348006.0
# 2              1          348020.0         348006.0
# 3              1          348025.0         348010.0
# 4              1          348025.0         348010.0
#
# [5 rows x 32 columns]

# %% [markdown]
# ### Filling the missing values in test data using random imputation

# %%
test_df_1.isnull().mean()*100
# Out:
# clientid_cr                       0.000000
# conversiontime_cr                 0.000000
# adslotdimid_cr                    0.000000
# algo_cr                           0.000000
# clickbid_cr                      32.967033
# geodimid_cr                       0.000000
# itemcolumbiaid_cr                 0.000000
# itemid_cr                         0.000000
# position_cr                       0.000000
# pubclientid_cr                    0.000000
# siteId_cr                         0.000000
# templateid_cr                     9.010989
# goalid_cr                         0.000000
# time_cr                           0.000000
# adLogType_cr                      0.000000
# v_cr                              0.000000
# pricingtype_cr                    0.000000
# osId_cr                           0.000000
# browserId_cr                      0.000000
# cityId_cr                         0.000000
# stateId_cr                        0.000000
# modelDimId_cr                     0.000000
# connTypeDimId_cr                  0.000000
# ispDimId_cr                       0.000000
# countryDimId_cr                   0.000000
# goalTypeId_cr                     0.000000
# conversionDurationInMillis_cr     0.000000
# impressionTimeInMillis_cr         0.000000
# osVerDimId_cr                     0.000000
# uuidSource_cr                     0.000000
# stateGrpDimId_cr                  9.230769
# cityGrpDimId_cr                  33.626374
# dtype: float64

# %%
cols_with_nan = [feature for feature in test_df_1.columns if test_df_1[feature].isnull().sum() != 0]

# %%
cols_with_nan
# Out:
# ['clickbid_cr', 'templateid_cr', 'stateGrpDimId_cr', 'cityGrpDimId_cr']

# %%
for feature in cols_with_nan:
    impute_nan(test_df_1, feature)
# Out:
# C:\Users\Sudharsan Baskar\anaconda3\lib\site-packages\pandas\core\indexing.py:1745: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %%
test_df_1.isnull().mean()*100
# Out:
# clientid_cr                      0.0
# conversiontime_cr                0.0
# adslotdimid_cr                   0.0
# algo_cr                          0.0
# clickbid_cr                      0.0
# geodimid_cr                      0.0
# itemcolumbiaid_cr                0.0
# itemid_cr                        0.0
# position_cr                      0.0
# pubclientid_cr                   0.0
# siteId_cr                        0.0
# templateid_cr                    0.0
# goalid_cr                        0.0
# time_cr                          0.0
# adLogType_cr                     0.0
# v_cr                             0.0
# pricingtype_cr                   0.0
# osId_cr                          0.0
# browserId_cr                     0.0
# cityId_cr                        0.0
# stateId_cr                       0.0
# modelDimId_cr                    0.0
# connTypeDimId_cr                 0.0
# ispDimId_cr                      0.0
# countryDimId_cr                  0.0
# goalTypeId_cr                    0.0
# conversionDurationInMillis_cr    0.0
# impressionTimeInMillis_cr        0.0
# osVerDimId_cr                    0.0
# uuidSource_cr                    0.0
# stateGrpDimId_cr                 0.0
# cityGrpDimId_cr                  0.0
# dtype: float64

# %%
test_df_1.head()
# Out:
#    clientid_cr  conversiontime_cr  adslotdimid_cr  algo_cr  clickbid_cr  \
# 0        82122      1620000000000          233531       38         0.90
# 1        75694      1620000000000          356952       20         3.10
# 2        75694      1620000000000          356952       18         3.10
# 3        30431      1620000000000          355768       21         1.50
# 4        30431      1620000000000          355768       21         2.79
#
#    geodimid_cr  itemcolumbiaid_cr  itemid_cr  position_cr  pubclientid_cr  \
# 0          145            5526656   53184285            3            2658
# 1          144            5488773   49504162            1           85030
# 2          144            5488088   49504161            1           85030
# 3          144            5614054   53607445            1               1
# 4          144            5614054   53607445            1               1
#
#    ...  connTypeDimId_cr  ispDimId_cr  countryDimId_cr  goalTypeId_cr  \
# 0  ...            264494       265618              145             10
# 1  ...            264496       280429              144             10
# 2  ...            264496       280429              144             10
# 3  ...            264496       280429              144             10
# 4  ...            264496       280429              144             10
#
#    conversionDurationInMillis_cr  impressionTimeInMillis_cr  osVerDimId_cr  \
# 0                         369206              1620000000000              0
# 1                           2298              1620000000000         199414
# 2                           5713              1620000000000         199414
# 3                          66670              1620000000000         360833
# 4                          53789              1620000000000         360833
#
#    uuidSource_cr  stateGrpDimId_cr  cityGrpDimId_cr
# 0              1          348023.0         348008.0
# 1              1          348020.0         348006.0
# 2              1          348020.0         348006.0
# 3              1          348025.0         348010.0
# 4              1          348025.0         348010.0
#
# [5 rows x 32 columns]

# %% [markdown]
# ### Feature scaling in test data

# %%
cols_to_scale = [feature for feature in test_df_1.columns]

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
test_df_1[cols_to_scale] = scaler.fit_transform(test_df_1[cols_to_scale])
# Out:
# <ipython-input-148-be5a0c43972b>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df_1[cols_to_scale] = scaler.fit_transform(test_df_1[cols_to_scale])
# C:\Users\Sudharsan Baskar\anaconda3\lib\site-packages\pandas\core\indexing.py:1736: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())

# %%
test_df_1.head()
# Out:
#    clientid_cr  conversiontime_cr  adslotdimid_cr   algo_cr  clickbid_cr  \
# 0     0.948582                0.0        0.456536  0.001423     0.000000
# 1     0.873600                0.0        0.996179  0.000731     0.128655
# 2     0.873600                0.0        0.996179  0.000654     0.128655
# 3     0.345616                0.0        0.991002  0.000769     0.035088
# 4     0.345616                0.0        0.991002  0.000769     0.110526
#
#    geodimid_cr  itemcolumbiaid_cr  itemid_cr   position_cr  pubclientid_cr  \
# 0      0.00346           0.960556   0.960560  1.530677e-08        0.031248
# 1      0.00000           0.944654   0.766087  5.102256e-09        1.000000
# 2      0.00000           0.944367   0.766087  5.102256e-09        1.000000
# 3      0.00000           0.997243   0.982921  5.102256e-09        0.000000
# 4      0.00000           0.997243   0.982921  5.102256e-09        0.000000
#
#    ...  connTypeDimId_cr  ispDimId_cr  countryDimId_cr  goalTypeId_cr  \
# 0  ...      0.000000e+00     0.928105          0.00346            0.0
# 1  ...      7.561553e-12     0.979856          0.00000            0.0
# 2  ...      7.561553e-12     0.979856          0.00000            0.0
# 3  ...      7.561553e-12     0.979856          0.00000            0.0
# 4  ...      7.561553e-12     0.979856          0.00000            0.0
#
#    conversionDurationInMillis_cr  impressionTimeInMillis_cr  osVerDimId_cr  \
# 0                       0.000248                        1.0       0.000000
# 1                       0.000001                        1.0       0.551710
# 2                       0.000003                        1.0       0.551710
# 3                       0.000044                        1.0       0.998301
# 4                       0.000036                        1.0       0.998301
#
#    uuidSource_cr  stateGrpDimId_cr  cityGrpDimId_cr
# 0            0.0          0.428571              0.6
# 1            0.0          0.000000              0.2
# 2            0.0          0.000000              0.2
# 3            0.0          0.714286              1.0
# 4            0.0          0.714286              1.0
#
# [5 rows x 32 columns]

# %% [markdown]
# ### Prediction

# %% [markdown]
# #### Using Random Forest

# %%
rf_model = RandomForestClassifier(n_estimators=40)
rf_model.fit(X, y)
# Out:
# RandomForestClassifier(n_estimators=40)

# %%
rf_result = rf_model.predict(test_df_1)
rf_result_df = pd.DataFrame(rf_result, columns=["conversion_fraud"])
Final_Prediction_df_rf = pd.concat([test_record_id, rf_result_df], axis="columns")
Final_Prediction_df_rf["conversion_fraud"] = Final_Prediction_df_rf["conversion_fraud"].map({1:True, 0:False})
Final_Prediction_df_rf.to_csv("result_rf.csv", index=False)

# %% [markdown]
# #### Using Decision Tree

# %%
dt_model = DecisionTreeClassifier(criterion='entropy')
dt_model.fit(X, y)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
dt_result = dt_model.predict(test_df_1)
dt_result_df = pd.DataFrame(dt_result, columns=["conversion_fraud"])
Final_Prediction_df_dt = pd.concat([test_record_id, dt_result_df], axis="columns")
Final_Prediction_df_dt["conversion_fraud"] = Final_Prediction_df_dt["conversion_fraud"].map({1:True, 0:False})
Final_Prediction_df_dt.to_csv("result_dt.csv", index=False)
